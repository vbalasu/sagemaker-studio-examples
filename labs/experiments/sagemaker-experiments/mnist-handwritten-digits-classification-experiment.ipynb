# %% [markdown]
# ## MNIST Handwritten Digits Classification Experiment
#
# This demo shows how you can use SageMaker Experiment Management Python SDK to organize, track, compare, and evaluate your machine learning (ML) model training experiments.
#
# You can track artifacts for experiments, including data sets, algorithms, hyper-parameters, and metrics. Experiments executed on SageMaker such as SageMaker Autopilot jobs and training jobs are automatically tracked will be automatically tracked. You can also track artifacts for additional steps within an ML workflow that come before/after model training e.g. data pre-processing or post-training model evaluation.
#
# The APIs also let you search and browse your current and past experiments, compare experiments, and identify best performing models.
#
# Now we will demonstrate these capabilities through an MNIST handwritten digits classification example. The experiment will be organized as follow:
#
# 1. Download and prepare the MNIST dataset.
# 2. Train a Convolutional Neural Network (CNN) Model. Tune the hyper parameter that configures the number of hidden channels in the model. Track the parameter configurations and resulting model accuracy using SageMaker Experiments Python SDK.
# 3. Finally use the search and analytics capabilities of Python SDK to search, compare and evaluate the performance of all model versions generated from model tuning in Step 2.
# 4. We will also see an example of tracing the complete linage of a model version i.e. the collection of all the data pre-processing and training configurations and inputs that went into creating that model version.
#
# Note this notebook can only be ran on sagemaker notebook instance with `conda_pytorch_p36` kernel.

# %% [markdown]
# ### Install Python SDKs

# %%
import sys

# %%
# !{sys.executable} -m pip install sagemaker-experiments
# Out:
# Requirement already satisfied: sagemaker-experiments in /opt/conda/lib/python3.6/site-packages (0.1.7)
# Requirement already satisfied: boto3>=1.10.32 in /opt/conda/lib/python3.6/site-packages (from sagemaker-experiments) (1.11.13)
# Requirement already satisfied: botocore<1.15.0,>=1.14.13 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.10.32->sagemaker-experiments) (1.14.13)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.10.32->sagemaker-experiments) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from boto3>=1.10.32->sagemaker-experiments) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3>=1.10.32->sagemaker-experiments) (0.14)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /opt/conda/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3>=1.10.32->sagemaker-experiments) (1.24.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.6/site-packages (from botocore<1.15.0,>=1.14.13->boto3>=1.10.32->sagemaker-experiments) (2.8.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.15.0,>=1.14.13->boto3>=1.10.32->sagemaker-experiments) (1.12.0)

# %% [markdown]
# ### Setup

# %%
import time

import boto3
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'retina'
from matplotlib import pyplot as plt
from torchvision import datasets, transforms

import sagemaker
from sagemaker.session import Session
from sagemaker.analytics import ExperimentAnalytics

from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

# %%
sess = boto3.Session()
sm = sess.client('sagemaker')
role = sagemaker.get_execution_role()

# %% [markdown]
# ### Create a S3 bucket to hold data

# %%
# create a s3 bucket to hold data, note that your account might already created a bucket with the same name
account_id = sess.client('sts').get_caller_identity()["Account"]
bucket = 'sagemaker-experiments-{}-{}'.format(sess.region_name, account_id)
prefix = 'mnist'

try:
    if sess.region_name == "us-east-1":
        sess.client('s3').create_bucket(Bucket=bucket)
    else:
        sess.client('s3').create_bucket(Bucket=bucket, 
                                        CreateBucketConfiguration={'LocationConstraint': sess.region_name})
except Exception as e:
    print(e)
# Out:
# An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %% [markdown]
# ### Dataset
# We download the MNIST hand written digits dataset, and then apply transformation on each of the image.

# %%
# download the dataset
# this will not only download data to ./mnist folder, but also load and transform (normalize) them
train_set = datasets.MNIST('mnist', train=True, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))]), 
    download=True)
                           
test_set = datasets.MNIST('mnist', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))]),
    download=False)
# Out:
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to mnist/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:00, 13201569.22it/s]
# Extracting mnist/MNIST/raw/train-images-idx3-ubyte.gz to mnist/MNIST/raw
# 32768it [00:00, 334260.65it/s]
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting mnist/MNIST/raw/train-labels-idx1-ubyte.gz to mnist/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 5240517.50it/s]
# Extracting mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to mnist/MNIST/raw
# 8192it [00:00, 86104.06it/s]
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to mnist/MNIST/raw
# Processing...
# Done!

# %%
plt.imshow(train_set.data[2].numpy())

# %% [markdown]
# After transforming the images in the dataset, we upload it to s3.

# %%
inputs = sagemaker.Session().upload_data(path='mnist', bucket=bucket, key_prefix=prefix)
print('input spec: {}'.format(inputs))
# Out:
# input spec: s3://sagemaker-experiments-us-east-2-308412838853/mnist

# %% [markdown]
# Now lets track the parameters from the data pre-processing step.

# %%
with Tracker.create(display_name="Preprocessing", sagemaker_boto_client=sm) as tracker:
    tracker.log_parameters({
        "normalization_mean": 0.1307,
        "normalization_std": 0.3081,
    })
    # we can log the s3 uri to the dataset we just uploaded
    tracker.log_input(name="mnist-dataset", media_type="s3/uri", value=inputs)

# %% [markdown]
# ### Step 1 - Set up the Experiment
#
# Create an experiment to track all the model training iterations. Experiments are a great way to organize your data science work. You can create experiments to organize all your model development work for : [1] a business use case you are addressing (e.g. create experiment named “customer churn prediction”), or [2] a data science team that owns the experiment (e.g. create experiment named “marketing analytics experiment”), or [3] a specific data science and ML project. Think of it as a “folder” for organizing your “files”.

# %% [markdown]
# ### Create an Experiment

# %%
mnist_experiment = Experiment.create(
    experiment_name=f"mnist-hand-written-digits-classification-{int(time.time())}", 
    description="Classification of mnist hand-written digits", 
    sagemaker_boto_client=sm)
print(mnist_experiment)
# Out:
# Experiment(sagemaker_boto_client=<botocore.client.SageMaker object at 0x7fb037c66208>,experiment_name='mnist-hand-written-digits-classification-1581456210',description='Classification of mnist hand-written digits',experiment_arn='arn:aws:sagemaker:us-east-2:308412838853:experiment/mnist-hand-written-digits-classification-1581456210',response_metadata={'RequestId': '2266d844-abbf-4361-b607-3bb8b2c63635', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '2266d844-abbf-4361-b607-3bb8b2c63635', 'content-type': 'application/x-amz-json-1.1', 'content-length': '123', 'date': 'Tue, 11 Feb 2020 21:23:30 GMT'}, 'RetryAttempts': 0})

# %% [markdown]
# ### Step 2 - Track Experiment

# %% [markdown]
# ### Now create a Trial for each training run to track the it's inputs, parameters, and metrics.

# %% [markdown]
# While training the CNN model on SageMaker, we will experiment with several values for the number of hidden channel in the model. We will create a Trial to track each training job run. We will also create a TrialComponent from the tracker we created before, and add to the Trial. This will enrich the Trial with the parameters we captured from the data pre-processing stage.
#
# Note the execution of the following code takes a while.

# %%
from sagemaker.pytorch import PyTorch

# %%
hidden_channel_trial_name_map = {}

# %% [markdown]
# If you want to run the following training jobs asynchronously, you may need to increase your resource limit. Otherwise, you can run them sequentially.

# %%
preprocessing_trial_component = tracker.trial_component

# %%
# %pwd
# Out:
# '/root/pocket/experiments/sagemaker-experiments'

# %%
# %cd pocket/experiments/sagemaker-experiments/
# Out:
# [Errno 2] No such file or directory: 'pocket/experiments/sagemaker-experiments/'
# /root/pocket/experiments/sagemaker-experiments

# %%
for i, num_hidden_channel in enumerate([2, 5, 10, 20, 32, 50]):
    # create trial
    trial_name = f"cnn-training-job-{num_hidden_channel}-hidden-channels-{int(time.time())}"
    cnn_trial = Trial.create(
        trial_name=trial_name, 
        experiment_name=mnist_experiment.experiment_name,
        sagemaker_boto_client=sm,
    )
    hidden_channel_trial_name_map[num_hidden_channel] = trial_name
    
    # associate the proprocessing trial component with the current trial
    cnn_trial.add_trial_component(preprocessing_trial_component)
    
    # all input configurations, parameters, and metrics specified in estimator 
    # definition are automatically tracked
    estimator = PyTorch(
        entry_point='./mnist.py',
        role=role,
        sagemaker_session=sagemaker.Session(sagemaker_client=sm),
        framework_version='1.1.0',
        train_instance_count=1,
        train_instance_type='ml.c4.xlarge',
        hyperparameters={
            'epochs': 2,
            'backend': 'gloo',
            'hidden_channels': num_hidden_channel,
            'dropout': 0.2,
            'optimizer': 'sgd'
        },
        metric_definitions=[
            {'Name':'train:loss', 'Regex':'Train Loss: (.*?);'},
            {'Name':'test:loss', 'Regex':'Test Average loss: (.*?),'},
            {'Name':'test:accuracy', 'Regex':'Test Accuracy: (.*?)%;'}
        ],
        enable_sagemaker_metrics=True,
    )
    
    cnn_training_job_name = "cnn-training-job-{}".format(int(time.time()))
    
    # Now associate the estimator with the Experiment and Trial
    estimator.fit(
        inputs={'training': inputs}, 
        job_name=cnn_training_job_name,
        experiment_config={
            "TrialName": cnn_trial.trial_name,
            "TrialComponentDisplayName": "Training",
        },
        wait=True,
    )
    
    # give it a while before dispatching the next training job
    time.sleep(2)
# Out:
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581456220
# 2020-02-11 21:23:40 Starting - Starting the training job...
# 2020-02-11 21:23:42 Starting - Launching requested ML instances...
# 2020-02-11 21:24:38 Starting - Preparing the instances for training......
# 2020-02-11 21:25:19 Downloading - Downloading input data...
# 2020-02-11 21:26:01 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:26:02,995 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:26:02,997 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:26:03,009 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:26:03,634 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:26:03,881 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:26:03,881 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:26:03,882 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:26:03,882 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pqfh2ve3/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:26:05,596 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:26:05,609 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 2,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581456220",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456220/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":2,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456220/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":2,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581456220","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456220/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","2","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=2
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 2 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.617049;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 0.941270;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.843992;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.432059;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.464780;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.322854;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.351526;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.389307;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.375780;
# Test Average loss: 0.1852, Test Accuracy: 95%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.275706;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.292543;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.244455;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.283167;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.279576;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.341436;
# Train Epoch: 2 [44800/60000 (75%)], Train Loss: 0.414407;
# Train Epoch: 2 [51200/60000 (85%)], Train Loss: 0.193495;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.157259;
# Test Average loss: 0.1158, Test Accuracy: 97%;
#
# Saving the model.
# 2020-02-11 21:26:46,226 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:26:55 Uploading - Uploading generated training model
# 2020-02-11 21:26:55 Completed - Training job completed
# Training seconds: 96
# Billable seconds: 96
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581456444
# 2020-02-11 21:27:24 Starting - Starting the training job...
# 2020-02-11 21:27:26 Starting - Launching requested ML instances...
# 2020-02-11 21:28:22 Starting - Preparing the instances for training......
# 2020-02-11 21:29:02 Downloading - Downloading input data...
# 2020-02-11 21:29:43 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:29:44,290 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:29:44,293 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:29:44,304 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:29:44,305 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:29:44,589 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:29:44,589 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:29:44,589 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:29:44,589 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z293_sqy/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:29:46,206 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:29:46,218 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 5,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581456444",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456444/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":5,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456444/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":5,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581456444","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456444/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","5","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=5
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 5 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.698200;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 0.994831;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.611539;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.648925;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.571486;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.791933;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.438099;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.549112;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.480673;
# Test Average loss: 0.1914, Test Accuracy: 94%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.297167;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.364907;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.268553;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.272427;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.382764;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.482188;
# Train Epoch: 2 [44800/60000 (75%)], Train Loss: 0.203590;
# Train Epoch: 2 [51200/60000 (85%)], Train Loss: 0.445356;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.197844;
# Test Average loss: 0.1157, Test Accuracy: 96%;
#
# Saving the model.
# 2020-02-11 21:30:27,657 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:30:36 Uploading - Uploading generated training model
# 2020-02-11 21:30:36 Completed - Training job completed
# Training seconds: 94
# Billable seconds: 94
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581456668
# 2020-02-11 21:31:08 Starting - Starting the training job...
# 2020-02-11 21:31:10 Starting - Launching requested ML instances...
# 2020-02-11 21:32:09 Starting - Preparing the instances for training......
# 2020-02-11 21:33:08 Downloading - Downloading input data...
# 2020-02-11 21:33:37 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:33:39,494 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:33:39,497 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:33:39,509 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:33:42,524 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:33:42,956 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:33:42,957 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:33:42,957 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:33:42,957 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e0entl5q/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:33:45,268 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:33:45,281 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 10,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581456668",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456668/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":10,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456668/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":10,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581456668","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456668/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","10","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=10
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 10 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.695285;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 0.928432;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.702160;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.442871;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.413667;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.501132;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.383585;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.328490;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.396089;
# Test Average loss: 0.1679, Test Accuracy: 95%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.603119;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.229334;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.281790;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.376957;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.412861;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.200810;
#
# 2020-02-11 21:34:38 Uploading - Uploading generated training modelTrain Epoch: 2 [44800/60000 (75%)], Train Loss: 0.233049;
# Train Epoch: 2 [51200/60000 (85%)], Train Loss: 0.319483;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.210030;
# Test Average loss: 0.1060, Test Accuracy: 97%;
#
# Saving the model.
# 2020-02-11 21:34:34,327 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:34:45 Completed - Training job completed
# Training seconds: 97
# Billable seconds: 97
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581456923
# 2020-02-11 21:35:23 Starting - Starting the training job...
# 2020-02-11 21:35:25 Starting - Launching requested ML instances...
# 2020-02-11 21:36:20 Starting - Preparing the instances for training......
# 2020-02-11 21:37:06 Downloading - Downloading input data...
# 2020-02-11 21:37:47 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:37:48,545 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:37:48,548 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:37:48,559 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:37:48,560 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:37:48,815 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:37:48,815 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:37:48,815 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:37:48,815 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-izf0uwbs/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:37:50,418 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:37:50,430 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 20,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581456923",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456923/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":20,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456923/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":20,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581456923","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581456923/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","20","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=20
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 20 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.621211;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 1.013725;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.799500;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.595724;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.411506;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.176120;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.317887;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.203233;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.264020;
# Test Average loss: 0.1407, Test Accuracy: 96%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.384039;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.200869;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.399078;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.451251;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.263621;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.151691;
# Train Epoch: 2 [44800/60000 (75%)], Train Loss: 0.375438;
#
# 2020-02-11 21:38:53 Uploading - Uploading generated training modelTrain Epoch: 2 [51200/60000 (85%)], Train Loss: 0.332934;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.227200;
# Test Average loss: 0.0965, Test Accuracy: 97%;
#
# Saving the model.
# 2020-02-11 21:38:49,562 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:39:01 Completed - Training job completed
# Training seconds: 115
# Billable seconds: 115
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581457177
# 2020-02-11 21:39:38 Starting - Starting the training job...
# 2020-02-11 21:39:40 Starting - Launching requested ML instances......
# 2020-02-11 21:41:03 Starting - Preparing the instances for training......
# 2020-02-11 21:41:43 Downloading - Downloading input data..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:42:23,465 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:42:23,468 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:42:23,479 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:42:23,480 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:42:23,717 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:42:23,718 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:42:23,718 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:42:23,718 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-as71rirr/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:42:25,313 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:42:25,325 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 32,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581457177",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457177/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":32,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457177/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":32,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581457177","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457177/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","32","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=32
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 32 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
#
# 2020-02-11 21:42:22 Training - Training image download completed. Training in progress.Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.461214;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 0.827845;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.747446;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.516501;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.465859;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.380938;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.451455;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.202041;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.379481;
# Test Average loss: 0.1531, Test Accuracy: 95%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.183234;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.523121;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.199367;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.200822;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.377310;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.227790;
# Train Epoch: 2 [44800/60000 (75%)], Train Loss: 0.642007;
#
# 2020-02-11 21:43:33 Uploading - Uploading generated training modelTrain Epoch: 2 [51200/60000 (85%)], Train Loss: 0.365126;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.101494;
# Test Average loss: 0.1012, Test Accuracy: 97%;
#
# Saving the model.
# 2020-02-11 21:43:32,841 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:43:41 Completed - Training job completed
# Training seconds: 118
# Billable seconds: 118
# INFO:sagemaker:Creating training-job with name: cnn-training-job-1581457462
# 2020-02-11 21:44:23 Starting - Starting the training job...
# 2020-02-11 21:44:24 Starting - Launching requested ML instances...
# 2020-02-11 21:45:19 Starting - Preparing the instances for training......
# 2020-02-11 21:46:11 Downloading - Downloading input data...
# 2020-02-11 21:46:43 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-02-11 21:46:45,179 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-02-11 21:46:45,181 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:46:45,193 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-02-11 21:46:46,733 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-02-11 21:46:46,981 sagemaker-containers INFO     Module mnist does not provide a setup.py.
# Generating setup.py
# 2020-02-11 21:46:46,981 sagemaker-containers INFO     Generating setup.cfg
# 2020-02-11 21:46:46,981 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-02-11 21:46:46,981 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: mnist
#   Running setup.py bdist_wheel for mnist: started
#   Running setup.py bdist_wheel for mnist: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qpbmb58p/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mnist
# Installing collected packages: mnist
# Successfully installed mnist-1.0.0
# You are using pip version 18.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-02-11 21:46:48,800 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-02-11 21:46:48,813 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "optimizer": "sgd",
#         "hidden_channels": 50,
#         "dropout": 0.2,
#         "backend": "gloo",
#         "epochs": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "cnn-training-job-1581457462",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457462/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":50,"optimizer":"sgd"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457462/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"backend":"gloo","dropout":0.2,"epochs":2,"hidden_channels":50,"optimizer":"sgd"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"cnn-training-job-1581457462","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-308412838853/cnn-training-job-1581457462/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--backend","gloo","--dropout","0.2","--epochs","2","--hidden_channels","50","--optimizer","sgd"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_OPTIMIZER=sgd
# SM_HP_HIDDEN_CHANNELS=50
# SM_HP_DROPOUT=0.2
# SM_HP_BACKEND=gloo
# SM_HP_EPOCHS=2
# PYTHONPATH=/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python -m mnist --backend gloo --dropout 0.2 --epochs 2 --hidden_channels 50 --optimizer sgd
#
#
# Distributed training - False
# Number of gpus available - 0
# Get train data loader
# Get test data loader
# Processes 60000/60000 (100%) of train data
# Processes 10000/10000 (100%) of test data
# Train Epoch: 1 [6400/60000 (11%)], Train Loss: 1.208308;
# Train Epoch: 1 [12800/60000 (21%)], Train Loss: 0.902680;
# Train Epoch: 1 [19200/60000 (32%)], Train Loss: 0.807761;
# Train Epoch: 1 [25600/60000 (43%)], Train Loss: 0.619479;
# Train Epoch: 1 [32000/60000 (53%)], Train Loss: 0.256478;
# Train Epoch: 1 [38400/60000 (64%)], Train Loss: 0.419667;
# Train Epoch: 1 [44800/60000 (75%)], Train Loss: 0.433821;
# Train Epoch: 1 [51200/60000 (85%)], Train Loss: 0.399015;
# Train Epoch: 1 [57600/60000 (96%)], Train Loss: 0.365275;
# Test Average loss: 0.1397, Test Accuracy: 96%;
#
# Train Epoch: 2 [6400/60000 (11%)], Train Loss: 0.435463;
# Train Epoch: 2 [12800/60000 (21%)], Train Loss: 0.256450;
# Train Epoch: 2 [19200/60000 (32%)], Train Loss: 0.435670;
# Train Epoch: 2 [25600/60000 (43%)], Train Loss: 0.230171;
# Train Epoch: 2 [32000/60000 (53%)], Train Loss: 0.110539;
# Train Epoch: 2 [38400/60000 (64%)], Train Loss: 0.278075;
# Train Epoch: 2 [44800/60000 (75%)], Train Loss: 0.382982;
# Train Epoch: 2 [51200/60000 (85%)], Train Loss: 0.181590;
# Train Epoch: 2 [57600/60000 (96%)], Train Loss: 0.235533;
# Test Average loss: 0.0858, Test Accuracy: 97%;
#
# Saving the model.
# 2020-02-11 21:48:21,465 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-02-11 21:48:33 Uploading - Uploading generated training model
# 2020-02-11 21:48:33 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142

# %% [markdown]
# ### Compare the model training runs for an experiment
#
# Now we will use the analytics capabilities of Python SDK to query and compare the training runs for identifying the best model produced by our experiment. You can retrieve trial components by using a search expression.

# %% [markdown]
# ### Some Simple Analyses

# %%
search_expression = {
    "Filters":[
        {
            "Name": "DisplayName",
            "Operator": "Equals",
            "Value": "Training",
        }
    ],
}

# %%
trial_component_analytics = ExperimentAnalytics(
    sagemaker_session=Session(sess, sm), 
    experiment_name=mnist_experiment.experiment_name,
    search_expression=search_expression,
    sort_by="metrics.test:accuracy.max",
    sort_order="Descending",
    metric_names=['test:accuracy'],
    parameter_names=['hidden_channels', 'epochs', 'dropout', 'optimizer']
)

# %%
analytic_table = trial_component_analytics.dataframe()

# %%
analytic_table
# Out:
#                              TrialComponentName DisplayName  \
# 0  cnn-training-job-1581457462-aws-training-job    Training
# 1  cnn-training-job-1581456220-aws-training-job    Training
# 2  cnn-training-job-1581457177-aws-training-job    Training
# 3  cnn-training-job-1581456668-aws-training-job    Training
# 4  cnn-training-job-1581456923-aws-training-job    Training
# 5  cnn-training-job-1581456444-aws-training-job    Training
#
#                                            SourceArn  dropout  epochs  \
# 0  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
# 1  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
# 2  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
# 3  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
# 4  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
# 5  arn:aws:sagemaker:us-east-2:308412838853:train...      0.2     2.0
#
#    hidden_channels optimizer  test:accuracy - Min  test:accuracy - Max  \
# 0             50.0     "sgd"                 96.0                 97.0
# 1              2.0     "sgd"                 95.0                 97.0
# 2             32.0     "sgd"                 95.0                 97.0
# 3             10.0     "sgd"                 95.0                 97.0
# 4             20.0     "sgd"                 96.0                 97.0
# 5              5.0     "sgd"                 94.0                 96.0
#
#    test:accuracy - Avg  test:accuracy - StdDev  test:accuracy - Last  \
# 0                 96.5                0.707107                  97.0
# 1                 96.0                1.414214                  97.0
# 2                 96.0                1.414214                  97.0
# 3                 96.0                1.414214                  97.0
# 4                 96.5                0.707107                  97.0
# 5                 95.0                1.414214                  96.0
#
#    test:accuracy - Count
# 0                      2
# 1                      2
# 2                      2
# 3                      2
# 4                      2
# 5                      2

# %% [markdown]
# To isolate and measure the impact of change in hidden channels on model accuracy, we vary the number of hidden channel and fix the value for other hyperparameters.
#
# Next let's look at an example of tracing the lineage of a model by accessing the data tracked by SageMaker Experiments for `cnn-training-job-2-hidden-channels` trial

# %%
lineage_table = ExperimentAnalytics(
    sagemaker_session=Session(sess, sm), 
    search_expression={
        "Filters":[{
            "Name": "Parents.TrialName",
            "Operator": "Equals",
            "Value": hidden_channel_trial_name_map[2]
        }]
    },
    sort_by="CreationTime",
    sort_order="Ascending",
)

# %%
lineage_table.dataframe()
# Out:
#                              TrialComponentName    DisplayName  \
# 0         TrialComponent-2020-02-11-212328-mkba  Preprocessing
# 1  cnn-training-job-1581456220-aws-training-job       Training
#
#    normalization_mean  normalization_std  \
# 0              0.1307             0.3081
# 1                 NaN                NaN
#
#                                            SourceArn  \
# 0                                                NaN
# 1  arn:aws:sagemaker:us-east-2:308412838853:train...
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 0                                                NaN                      NaN
# 1  520713654638.dkr.ecr.us-east-2.amazonaws.com/s...                      1.0
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB backend  ...  \
# 0                    NaN                       NaN     NaN  ...
# 1           ml.c4.xlarge                      30.0  "gloo"  ...
#
#    test:accuracy - Avg  test:accuracy - StdDev  test:accuracy - Last  \
# 0                  NaN                     NaN                   NaN
# 1                 96.0                1.414214                  97.0
#
#   test:accuracy - Count  train:loss - Min train:loss - Max train:loss - Avg  \
# 0                   NaN               NaN              NaN              NaN
# 1                   2.0          0.157259         1.617049         0.456703
#
#   train:loss - StdDev train:loss - Last train:loss - Count
# 0                 NaN               NaN                NaN
# 1            0.352488          0.157259               18.0
#
# [2 rows x 38 columns]
