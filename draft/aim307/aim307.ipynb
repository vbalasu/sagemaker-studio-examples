# %% [markdown]
# # Direct Marketing with XGBoost and Amazon SageMaker
#
# Featuring SageMaker AutoPilot, SageMaker Processing, SageMaker Experiments, and SageMaker Model Monitoring
#
# Last update: December 3rd, 2019
#
# ### https://gitlab.com/juliensimon/aim307
# ### Twitter: @julsimon

# %%
# !pip install sagemaker smdebug --upgrade
# Out:
# Requirement already up-to-date: sagemaker in /opt/conda/lib/python3.7/site-packages (1.45.1)
# Requirement already up-to-date: smdebug in /opt/conda/lib/python3.7/site-packages (0.4.14)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (1.3.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (3.9.2)
# Requirement already satisfied, skipping upgrade: protobuf3-to-dict>=0.1.5 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied, skipping upgrade: smdebug-rulesconfig==0.1.2 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (0.1.2)
# Requirement already satisfied, skipping upgrade: boto3>=1.10.32 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (1.10.32)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (1.17.3)
# Requirement already satisfied, skipping upgrade: requests<2.21,>=2.20.0 in /opt/conda/lib/python3.7/site-packages (from sagemaker) (2.20.1)
# Requirement already satisfied, skipping upgrade: aiohttp<4.0,>=3.6.0 in /opt/conda/lib/python3.7/site-packages (from smdebug) (3.6.2)
# Requirement already satisfied, skipping upgrade: packaging in /opt/conda/lib/python3.7/site-packages (from smdebug) (19.2)
# Requirement already satisfied, skipping upgrade: botocore==1.13.32 in /opt/conda/lib/python3.7/site-packages (from smdebug) (1.13.32)
# Requirement already satisfied, skipping upgrade: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from smdebug) (1.2.1)
# Requirement already satisfied, skipping upgrade: aioboto3==6.4.1 in /opt/conda/lib/python3.7/site-packages (from smdebug) (6.4.1)
# Requirement already satisfied, skipping upgrade: aiobotocore==0.11.0 in /opt/conda/lib/python3.7/site-packages (from smdebug) (0.11.0)
# Requirement already satisfied, skipping upgrade: six>=1.9 in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.1->sagemaker) (1.13.0)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.1->sagemaker) (42.0.2.post20191201)
# Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from boto3>=1.10.32->sagemaker) (0.2.1)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from boto3>=1.10.32->sagemaker) (0.9.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.8,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (2.7)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (1.24.3)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6.0->smdebug) (1.4.2)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6.0->smdebug) (3.0.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6.0->smdebug) (19.3.0)
# Requirement already satisfied, skipping upgrade: multidict<5.0,>=4.5 in /opt/conda/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6.0->smdebug) (4.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->smdebug) (2.4.5)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /opt/conda/lib/python3.7/site-packages (from botocore==1.13.32->smdebug) (0.15.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /opt/conda/lib/python3.7/site-packages (from botocore==1.13.32->smdebug) (2.8.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.10.10 in /opt/conda/lib/python3.7/site-packages (from aiobotocore==0.11.0->smdebug) (1.11.2)
# Requirement already satisfied, skipping upgrade: async-generator>=1.10 in /opt/conda/lib/python3.7/site-packages (from aiobotocore==0.11.0->smdebug) (1.10)

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import boto3
import sagemaker
import os, sys

print (sagemaker.__version__)

sess   = sagemaker.Session()
bucket = sess.default_bucket()                     
prefix = 'sagemaker/DEMO-automl-dm'
region = boto3.Session().region_name

# Role when working on a notebook instance
role = sagemaker.get_execution_role()
# Out:
# 1.45.1
# Couldn't call 'describe_notebook_instance' to get the Role ARN of the instance datascience.

# %%
sm = boto3.Session().client(service_name='sagemaker',region_name=region)
sm_rt = boto3.Session().client('runtime.sagemaker', region_name=region)

# %%
import numpy as np 
import pandas as pd

# %%
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# !unzip -o bank-additional.zip
# Out:
# --2019-12-09 20:54:11--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘bank-additional.zip’ not modified on server. Omitting download.
#
# Archive:  bank-additional.zip
#   inflating: bank-additional/.DS_Store
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %% [markdown]
# Let's read the CSV file into a Pandas data frame and take a look at the first few lines.

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pd.read_csv('./bank-additional/bank-additional-full.csv', sep=';')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page
data[:10] # Show the first 10 lines
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   may         mon       261         1    999         0
# 1  telephone   may         mon       149         1    999         0
# 2  telephone   may         mon       226         1    999         0
# 3  telephone   may         mon       151         1    999         0
# 4  telephone   may         mon       307         1    999         0
# 5  telephone   may         mon       198         1    999         0
# 6  telephone   may         mon       139         1    999         0
# 7  telephone   may         mon       217         1    999         0
# 8  telephone   may         mon       380         1    999         0
# 9  telephone   may         mon        50         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
# 5  nonexistent           1.1          93.994          -36.4      4.857
# 6  nonexistent           1.1          93.994          -36.4      4.857
# 7  nonexistent           1.1          93.994          -36.4      4.857
# 8  nonexistent           1.1          93.994          -36.4      4.857
# 9  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed   y
# 0       5191.0  no
# 1       5191.0  no
# 2       5191.0  no
# 3       5191.0  no
# 4       5191.0  no
# 5       5191.0  no
# 6       5191.0  no
# 7       5191.0  no
# 8       5191.0  no
# 9       5191.0  no

# %%
data.shape # (number of lines, number of columns)
# Out:
# (41188, 21)

# %% [markdown]
# ## Splitting the dataset
#
# We split the dataset into training (95%) and test (5%) datasets. We will use the training dataset for AutoML, where it will be automatically split again for training and validation.
#
# Once the model has been deployed, we'll use the test dataset to evaluate its performance.

# %%
# Set the seed to 123 for reproductibility
# https://pandas.pydata.org/pandas-docs/version/0.25/generated/pandas.DataFrame.sample.html
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.split.html
train_data, test_data, _ = np.split(data.sample(frac=1, random_state=123), 
                                                  [int(0.95 * len(data)), int(len(data))])  

# Save to CSV files
train_data.to_csv('automl-train.csv', index=False, header=True, sep=',') # Need to keep column names
test_data.to_csv('automl-test.csv', index=False, header=True, sep=',')

# %%
# !ls -l automl*.csv
# Out:
# -rw-r--r-- 1 root root  257339 Dec  9 20:54 automl-test.csv
# -rw-r--r-- 1 root root 4889516 Dec  9 20:54 automl-train.csv

# %% [markdown]
# **No preprocessing needed!** AutoML will take care of this, so let's just copy the training set to S3.

# %%
sess.upload_data(path="automl-train.csv", key_prefix=prefix + "/input")
# Out:
# 's3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/input/automl-train.csv'

# %% [markdown]
# ## Setting up the Amazon SageMaker AutoPilot job
#
# After uploading the dataset to S3, we can invoke SageMaker AutoPilot to find the best ML pipeline to train a model on this dataset.
#
# The required inputs for invoking a SageMaker AutoML job are the dataset location in S3, the name of the column of the dataset you want to predict (`y` in this case) and an IAM role.

# %%
job_config = {
    'CompletionCriteria': {
      'MaxRuntimePerTrainingJobInSeconds': 600,
      'MaxCandidates': 10,
      'MaxAutoMLJobRuntimeInSeconds': 3600
    },
}

input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/input'.format(bucket,prefix)
        }
      },
      'TargetAttributeName': 'y'  # the column we want to predict
    }
]

output_data_config = {
    'S3OutputPath': 's3://{}/{}/output'.format(bucket,prefix)
}

# %% [markdown]
# ## Launching the Amazon SageMaker AutoPilot job
#
# We can now launch the job by calling the `create_auto_ml_job` API.

# %%
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = 'automl-dm-' + timestamp_suffix
print('AutoMLJobName: ' + auto_ml_job_name)

sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig=job_config,
                      RoleArn=role)
# Out:
# AutoMLJobName: automl-dm-09-20-54-14
# {'AutoMLJobArn': 'arn:aws:sagemaker:us-east-2:308412838853:automl-job/automl-dm-09-20-54-14',
#  'ResponseMetadata': {'RequestId': 'e422a23d-41af-497c-8b58-ff177baea3f2',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'e422a23d-41af-497c-8b58-ff177baea3f2',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '92',
#    'date': 'Mon, 09 Dec 2019 20:54:14 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Tracking the progress of the Amazon SageMaker AutoPilot job
# SageMaker AutoPilot job consists of four high-level steps :
# * Data Preprocessing, where the dataset is split into train and validation sets.
# * Recommending Pipelines, where the dataset is analyzed and SageMaker AutoPilot comes up with a list of ML pipelines that should be tried out on the dataset.
# * Automatic Feature Engineering, where SageMaker AutoPilot performs feature transformation on individual features of the dataset as well as at an aggregate level.
# * ML pipeline selection and hyperparameter tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline).
#
# As you can guess, several of these steps are powered by **Amazon SageMaker Processing**.

# %%
# %%time
job_run_status = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['AutoMLJobStatus']

print(job_run_status)

while job_run_status not in ('Failed', 'Completed', 'Stopped'):
    describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    job_run_status = describe_response['AutoMLJobStatus']
    
    print (describe_response['AutoMLJobStatus'] + " - " + describe_response['AutoMLJobSecondaryStatus'])
    sleep(60)
# Out:
# InProgress
# InProgress - Starting
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# 11  automl-dm-09-20-54-14-automl-dm--dpp8-csv-1-09...
# 12  automl-dm-09-20-54-14-automl-dm--dpp6-csv-1-80...
# 13  automl-dm-09-20-54-14-automl-dm--dpp7-rpb-1-6d...
# 14  automl-dm-09-20-54-14-automl-dm--dpp5-rpb-1-76...
# 15  automl-dm-09-20-54-14-automl-dm--dpp9-1-d35278...
# 16  automl-dm-09-20-54-14-automl-dm--dpp8-1-c78f82...
# 17  automl-dm-09-20-54-14-automl-dm--dpp7-1-925279...
# 18  automl-dm-09-20-54-14-automl-dm--dpp6-1-9e9f68...
# 19  automl-dm-09-20-54-14-automl-dm--dpp5-1-d3a36f...
# 20  automl-dm-09-20-54-14-automl-dm--dpp4-rpb-1-e4...
# 21  automl-dm-09-20-54-14-automl-dm--dpp2-rpb-1-cf...
# 22  automl-dm-09-20-54-14-automl-dm--dpp1-csv-1-95...
# 23  automl-dm-09-20-54-14-automl-dm--dpp2-1-e34550...
# 24  automl-dm-09-20-54-14-automl-dm--dpp4-1-24bb8a...
# 25  automl-dm-09-20-54-14-automl-dm--dpp1-1-ada1a3...
# 26  automl-dm-09-20-54-14-db-1-9a579496b5a541c1b11...
#
#                                             SourceArn  \
# 0   arn:aws:sagemaker:us-east-2:308412838853:train...
# 1   arn:aws:sagemaker:us-east-2:308412838853:train...
# 2   arn:aws:sagemaker:us-east-2:308412838853:train...
# 3   arn:aws:sagemaker:us-east-2:308412838853:train...
# 4   arn:aws:sagemaker:us-east-2:308412838853:train...
# 5   arn:aws:sagemaker:us-east-2:308412838853:train...
# 6   arn:aws:sagemaker:us-east-2:308412838853:train...
# 7   arn:aws:sagemaker:us-east-2:308412838853:train...
# 8   arn:aws:sagemaker:us-east-2:308412838853:train...
# 9   arn:aws:sagemaker:us-east-2:308412838853:train...
# 10  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 11  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 12  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 13  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 14  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 15  arn:aws:sagemaker:us-east-2:308412838853:train...
# 16  arn:aws:sagemaker:us-east-2:308412838853:train...
# 17  arn:aws:sagemaker:us-east-2:308412838853:train...
# 18  arn:aws:sagemaker:us-east-2:308412838853:train...
# 19  arn:aws:sagemaker:us-east-2:308412838853:train...
# 20  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 21  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 22  arn:aws:sagemaker:us-east-2:308412838853:trans...
# 23  arn:aws:sagemaker:us-east-2:308412838853:train...
# 24  arn:aws:sagemaker:us-east-2:308412838853:train...
# 25  arn:aws:sagemaker:us-east-2:308412838853:train...
# 26  arn:aws:sagemaker:us-east-2:308412838853:proce...
#
#                                    SageMaker.ImageUri  \
# 0   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 1   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 2   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 3   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 4   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 5   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 6   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 7   257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 8   404615174143.dkr.ecr.us-east-2.amazonaws.com/l...
# 9   404615174143.dkr.ecr.us-east-2.amazonaws.com/l...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 16  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 17  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 18  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 19  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 24  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 25  257758044811.dkr.ecr.us-east-2.amazonaws.com/s...
# 26                                                NaN
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       1.0          ml.m5.4xlarge                      50.0
# 1                       1.0          ml.m5.4xlarge                      50.0
# 2                       1.0          ml.m5.4xlarge                      50.0
# 3                       1.0          ml.m5.4xlarge                      50.0
# 4                       1.0          ml.m5.4xlarge                      50.0
# 5                       1.0          ml.m5.4xlarge                      50.0
# 6                       1.0          ml.m5.4xlarge                      50.0
# 7                       1.0          ml.m5.4xlarge                      50.0
# 8                       1.0          ml.m5.4xlarge                      50.0
# 9                       1.0          ml.m5.4xlarge                      50.0
# 10                      1.0          ml.m5.4xlarge                       NaN
# 11                      1.0          ml.m5.4xlarge                       NaN
# 12                      1.0          ml.m5.4xlarge                       NaN
# 13                      1.0          ml.m5.4xlarge                       NaN
# 14                      1.0          ml.m5.4xlarge                       NaN
# 15                      1.0          ml.m5.4xlarge                      50.0
# 16                      1.0          ml.m5.4xlarge                      50.0
# 17                      1.0          ml.m5.4xlarge                      50.0
# 18                      1.0          ml.m5.4xlarge                      50.0
# 19                      1.0          ml.m5.4xlarge                      50.0
# 20                      1.0          ml.m5.4xlarge                       NaN
# 21                      1.0          ml.m5.4xlarge                       NaN
# 22                      1.0          ml.m5.4xlarge                       NaN
# 23                      1.0          ml.m5.4xlarge                      50.0
# 24                      1.0          ml.m5.4xlarge                      50.0
# 25                      1.0          ml.m5.4xlarge                      50.0
# 26                      1.0          ml.m5.2xlarge                     250.0
#
#                      _tuning_objective_metric     alpha  colsample_bytree  \
# 0                         validation:accuracy  0.390184          0.634997
# 1                         validation:accuracy  0.390184          0.634997
# 2                         validation:accuracy  0.390184          0.634997
# 3                         validation:accuracy  0.390184          0.634997
# 4                         validation:accuracy  0.390184          0.634997
# 5                         validation:accuracy  0.000140          0.446730
# 6                         validation:accuracy  0.390184          0.634997
# 7                         validation:accuracy  0.390184          0.634997
# 8   validation:binary_classification_accuracy       NaN               NaN
# 9   validation:binary_classification_accuracy       NaN               NaN
# 10                                        NaN       NaN               NaN
# 11                                        NaN       NaN               NaN
# 12                                        NaN       NaN               NaN
# 13                                        NaN       NaN               NaN
# 14                                        NaN       NaN               NaN
# 15                                        NaN       NaN               NaN
# 16                                        NaN       NaN               NaN
# 17                                        NaN       NaN               NaN
# 18                                        NaN       NaN               NaN
# 19                                        NaN       NaN               NaN
# 20                                        NaN       NaN               NaN
# 21                                        NaN       NaN               NaN
# 22                                        NaN       NaN               NaN
# 23                                        NaN       NaN               NaN
# 24                                        NaN       NaN               NaN
# 25                                        NaN       NaN               NaN
# 26                                        NaN       NaN               NaN
#
#          eta     gamma    lambda  max_depth  min_child_weight  num_round  \
# 0   0.695155  0.000007  0.000105       23.0         14.236520      399.0
# 1   0.695155  0.000007  0.000105       23.0         14.236520      399.0
# 2   0.695155  0.000007  0.000105       23.0         14.236520      399.0
# 3   0.695155  0.000007  0.000105       23.0         14.236520      399.0
# 4   0.695155  0.000007  0.000105       23.0         14.236520      399.0
# 5   0.004822  0.000156  0.000079        9.0          1.225687      252.0
# 8                         NaN                        NaN
# 9                         NaN                        NaN
# 10                        NaN                        NaN
# 11                        NaN                        NaN
# 12                        NaN                        NaN
# 13                        NaN                        NaN
# 14                        NaN                        NaN
# 15                        NaN                        NaN
# 16                        NaN                        NaN
# 17                        NaN                        NaN
# 18                        NaN                        NaN
# 19                        NaN                        NaN
# 20                        NaN                        NaN
# 21                        NaN                        NaN
# 22                        NaN                        NaN
# 23                        NaN                        NaN
# 24                        NaN                        NaN
# 25                        NaN                        NaN
# 26                        NaN                        NaN
#
#     validation:accuracy - Avg  validation:accuracy - StdDev  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                    0.904695                      0.010671
# 3                         NaN                           NaN
# 4                    0.899851                      0.010046
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                    0.900276                      0.010985
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
# 21                        NaN                           NaN
# 22                        NaN                           NaN
# 23                        NaN                           NaN
# 24                        NaN                           NaN
# 25                        NaN                           NaN
# 26                        NaN                           NaN
#
#     validation:accuracy - Last  validation:accuracy - Count  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                     0.903642                         34.0
# 3                          NaN                          NaN
# 4                     0.895847                         48.0
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                     0.897891                         41.0
# 8                          NaN                          NaN
# 9                          NaN                          NaN
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 12                         NaN                          NaN
# 13                         NaN                          NaN
# 14                         NaN                          NaN
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                         NaN                          NaN
# 20                         NaN                          NaN
# 21                         NaN                          NaN
# 22                         NaN                          NaN
# 23                         NaN                          NaN
# 24                         NaN                          NaN
# 25                         NaN                          NaN
# 26                         NaN                          NaN
#
#     train:error - Min  train:error - Max  train:error - Avg  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.036259           0.150401           0.054594
# 3                 NaN                NaN                NaN
# 4            0.031818           0.157780           0.053143
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7            0.034949           0.155959           0.053113
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
#
#     train:error - StdDev  train:error - Last  train:error - Count  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2               0.020841            0.036322                 34.0
# 3                    NaN                 NaN                  NaN
# 4               0.023455            0.031818                 48.0
# 5                    NaN                 NaN                  NaN
# 6                    NaN                 NaN                  NaN
# 7               0.021344            0.035077                 41.0
# 8                    NaN                 NaN                  NaN
# 9                    NaN                 NaN                  NaN
# 10                   NaN                 NaN                  NaN
# 11                   NaN                 NaN                  NaN
# 12                   NaN                 NaN                  NaN
# 13                   NaN                 NaN                  NaN
# 14                   NaN                 NaN                  NaN
# 15                   NaN                 NaN                  NaN
# 16                   NaN                 NaN                  NaN
# 17                   NaN                 NaN                  NaN
# 18                   NaN                 NaN                  NaN
# 19                   NaN                 NaN                  NaN
# 20                   NaN                 NaN                  NaN
# 21                   NaN                 NaN                  NaN
# 22                   NaN                 NaN                  NaN
# 23                   NaN                 NaN                  NaN
# 24                   NaN                 NaN                  NaN
# 25                   NaN                 NaN                  NaN
# 26                   NaN                 NaN                  NaN
#
#     train:accuracy - Min  train:accuracy - Max  train:accuracy - Avg  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2               0.849599              0.963741              0.945406
# 3                    NaN                   NaN                   NaN
# 4               0.842220              0.968182              0.946858
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7               0.844041              0.965051              0.946887
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
# 17                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   NaN
# 19                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 22                   NaN                   NaN                   NaN
# 23                   NaN                   NaN                   NaN
# 24                   NaN                   NaN                   NaN
# 25                   NaN                   NaN                   NaN
# 26                   NaN                   NaN                   NaN
#
#     train:accuracy - StdDev  train:accuracy - Last  train:accuracy - Count  \
# 0                       NaN                    NaN                     NaN
# 1                       NaN                    NaN                     NaN
# 2                  0.020841               0.963678                    34.0
# 3                       NaN                    NaN                     NaN
# 4                  0.023455               0.968182                    48.0
# 5                       NaN                    NaN                     NaN
# 6                       NaN                    NaN                     NaN
# 7                  0.021344               0.964923                    41.0
# 8                       NaN                    NaN                     NaN
# 9                       NaN                    NaN                     NaN
# 10                      NaN                    NaN                     NaN
# 11                      NaN                    NaN                     NaN
# 12                      NaN                    NaN                     NaN
# 13                      NaN                    NaN                     NaN
# 14                      NaN                    NaN                     NaN
# 15                      NaN                    NaN                     NaN
# 16                      NaN                    NaN                     NaN
# 17                      NaN                    NaN                     NaN
# 18                      NaN                    NaN                     NaN
# 19                      NaN                    NaN                     NaN
# 20                      NaN                    NaN                     NaN
# 21                      NaN                    NaN                     NaN
# 22                      NaN                    NaN                     NaN
# 23                      NaN                    NaN                     NaN
# 24                      NaN                    NaN                     NaN
# 25                      NaN                    NaN                     NaN
# 26                      NaN                    NaN                     NaN
#
#    binary_classifier_model_selection_criteria        l1  learning_rate  \
# 0                                         NaN       NaN            NaN
# 1                                         NaN       NaN            NaN
# 2                                         NaN       NaN            NaN
# 3                                         NaN       NaN            NaN
# 4                                         NaN       NaN            NaN
# 5                                         NaN       NaN            NaN
# 6                                         NaN       NaN            NaN
# 7                                         NaN       NaN            NaN
# 8                               loss_function  0.000018       0.032210
# 9                               loss_function  0.162744       0.002471
# 10                                        NaN       NaN            NaN
# 11                                        NaN       NaN            NaN
# 12                                        NaN       NaN            NaN
# 13                                        NaN       NaN            NaN
# 14                                        NaN       NaN            NaN
# 15                                        NaN       NaN            NaN
# 16                                        NaN       NaN            NaN
# 17                                        NaN       NaN            NaN
# 18                                        NaN       NaN            NaN
# 19                                        NaN       NaN            NaN
# 20                                        NaN       NaN            NaN
# 21                                        NaN       NaN            NaN
# 22                                        NaN       NaN            NaN
# 23                                        NaN       NaN            NaN
# 24                                        NaN       NaN            NaN
# 25                                        NaN       NaN            NaN
# 26                                        NaN       NaN            NaN
#
#         loss  mini_batch_size  num_models positive_example_weight_mult  \
# 0        NaN              NaN         NaN                          NaN
# 1        NaN              NaN         NaN                          NaN
# 2        NaN              NaN         NaN                          NaN
# 3        NaN              NaN         NaN                          NaN
# 4        NaN              NaN         NaN                          NaN
# 5        NaN              NaN         NaN                          NaN
# 6        NaN              NaN         NaN                          NaN
# 7        NaN              NaN         NaN                          NaN
# 8   logistic           1000.0         1.0                     balanced
# 9   logistic           1000.0         1.0                     balanced
# 10       NaN              NaN         NaN                          NaN
# 11       NaN              NaN         NaN                          NaN
# 12       NaN              NaN         NaN                          NaN
# 13       NaN              NaN         NaN                          NaN
# 14       NaN              NaN         NaN                          NaN
# 15       NaN              NaN         NaN                          NaN
# 16       NaN              NaN         NaN                          NaN
# 17       NaN              NaN         NaN                          NaN
# 18       NaN              NaN         NaN                          NaN
# 19       NaN              NaN         NaN                          NaN
# 20       NaN              NaN         NaN                          NaN
# 21       NaN              NaN         NaN                          NaN
# 22       NaN              NaN         NaN                          NaN
# 23       NaN              NaN         NaN                          NaN
# 24       NaN              NaN         NaN                          NaN
# 25       NaN              NaN         NaN                          NaN
# 26       NaN              NaN         NaN                          NaN
#
#        predictor_type            wd                processor_module  \
# 0                 NaN           NaN                             NaN
# 1                 NaN           NaN                             NaN
# 2                 NaN           NaN                             NaN
# 3                 NaN           NaN                             NaN
# 4                 NaN           NaN                             NaN
# 5                 NaN           NaN                             NaN
# 6                 NaN           NaN                             NaN
# 7                 NaN           NaN                             NaN
# 8   binary_classifier  2.765714e-02                             NaN
# 9   binary_classifier  5.711623e-07                             NaN
# 10                NaN           NaN                             NaN
# 11                NaN           NaN                             NaN
# 12                NaN           NaN                             NaN
# 13                NaN           NaN                             NaN
# 14                NaN           NaN                             NaN
# 15                NaN           NaN  candidate_data_processors.dpp9
# 16                NaN           NaN  candidate_data_processors.dpp8
# 17                NaN           NaN  candidate_data_processors.dpp7
# 18                NaN           NaN  candidate_data_processors.dpp6
# 19                NaN           NaN  candidate_data_processors.dpp5
# 20                NaN           NaN                             NaN
# 21                NaN           NaN                             NaN
# 22                NaN           NaN                             NaN
# 23                NaN           NaN  candidate_data_processors.dpp2
# 24                NaN           NaN  candidate_data_processors.dpp4
# 25                NaN           NaN  candidate_data_processors.dpp1
# 26                NaN           NaN                             NaN
#
#                     sagemaker_program sagemaker_submit_directory  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# 5                                 NaN                        NaN
# 6                                 NaN                        NaN
# 7                                 NaN                        NaN
# 8                                 NaN                        NaN
# 9                                 NaN                        NaN
# 10                                NaN                        NaN
# 11                                NaN                        NaN
# 12                                NaN                        NaN
# 13                                NaN                        NaN
# 14                                NaN                        NaN
# 15  candidate_data_processors.trainer    /opt/ml/input/data/code
# 16  candidate_data_processors.trainer    /opt/ml/input/data/code
# 17  candidate_data_processors.trainer    /opt/ml/input/data/code
# 18  candidate_data_processors.trainer    /opt/ml/input/data/code
# 19  candidate_data_processors.trainer    /opt/ml/input/data/code
# 20                                NaN                        NaN
# 21                                NaN                        NaN
# 22                                NaN                        NaN
# 23  candidate_data_processors.trainer    /opt/ml/input/data/code
# 24  candidate_data_processors.trainer    /opt/ml/input/data/code
# 25  candidate_data_processors.trainer    /opt/ml/input/data/code
# 26                                NaN                        NaN
#
#    input_channel_mode               job_name label_col
# 0                 NaN                    NaN       NaN
# 1                 NaN                    NaN       NaN
# 2                 NaN                    NaN       NaN
# 3                 NaN                    NaN       NaN
# 4                 NaN                    NaN       NaN
# 5                 NaN                    NaN       NaN
# 6                 NaN                    NaN       NaN
# 7                 NaN                    NaN       NaN
# 8                 NaN                    NaN       NaN
# 9                 NaN                    NaN       NaN
# 10                NaN                    NaN       NaN
# 11                NaN                    NaN       NaN
# 12                NaN                    NaN       NaN
# 13                NaN                    NaN       NaN
# 14                NaN                    NaN       NaN
# 15                NaN                    NaN       NaN
# 16                NaN                    NaN       NaN
# 17                NaN                    NaN       NaN
# 18                NaN                    NaN       NaN
# 19                NaN                    NaN       NaN
# 20                NaN                    NaN       NaN
# 21                NaN                    NaN       NaN
# 22                NaN                    NaN       NaN
# 23                NaN                    NaN       NaN
# 24                NaN                    NaN       NaN
# 25                NaN                    NaN       NaN
# 26               Pipe  automl-dm-09-20-54-14         y

# %% [markdown]
# ### Listing all candidates explored by Amazon SageMaker AutoPilot
# You can view all the candidates (pipeline evaluations with different hyperparameter combinations) that were explored by AutoML and sort them by their final performance metric.

# %%
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name, 
                                                SortBy='FinalObjectiveMetricValue')['Candidates']
index = 1
for candidate in candidates:
  print (str(index) + "  " 
         + candidate['CandidateName'] + "  " 
         + str(candidate['FinalAutoMLJobObjectiveMetric']['Value']))
  index += 1
# Out:
# 1  automl-dm-09-tuning-job-1-a4c13-001-f3bea0f5  0.9083709716796875
# 2  automl-dm-09-tuning-job-1-a4c13-005-904dfc1d  0.8944410085678101
# 3  automl-dm-09-tuning-job-1-a4c13-004-43dfe6cc  0.8943129777908325
# 4  automl-dm-09-tuning-job-1-a4c13-006-0dc434e1  0.8940579891204834
# 5  automl-dm-09-tuning-job-1-a4c13-008-3798c7b3  0.8940579891204834
# 6  automl-dm-09-tuning-job-1-a4c13-003-e6b6e697  0.8936740159988403
# 7  automl-dm-09-tuning-job-1-a4c13-007-43202bbe  0.8916289806365967
# 8  automl-dm-09-tuning-job-1-a4c13-009-e2d4dedb  0.8897119760513306
# 9  automl-dm-09-tuning-job-1-a4c13-002-3ab46f0a  0.865175724029541
# 10  automl-dm-09-tuning-job-1-a4c13-010-0a6aa84f  0.8554632663726807

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_name = best_candidate['CandidateName']

print("Candidate name: " + best_candidate_name)
# Out:
# Candidate name: automl-dm-09-tuning-job-1-a4c13-001-f3bea0f5

# %% [markdown]
# We can also see the containers and models composing the Inference Pipeline.

# %%
for container in best_candidate['InferenceContainers']:
    print(container['Image'])
    print(container['ModelDataUrl'])
    print('-')
# Out:
# 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/data-processor-models/automl-dm-09-20-54-14-automl-dm--dpp7-1-9252790552f84016825a692/output/model.tar.gz
# -
# 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3
# s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/tuning/automl-dm--dpp7-xgb/automl-dm-09-tuning-job-1-a4c13-001-f3bea0f5/output/model.tar.gz
# -
# 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/data-processor-models/automl-dm-09-20-54-14-automl-dm--dpp7-1-9252790552f84016825a692/output/model.tar.gz
# -

# %% [markdown]
# ### Fetching the auto-generated notebooks

# %% [markdown]
# SageMaker AutoPilot also generates two notebooks:
# * Data exploration,
# * Candidate definition.

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']

print(job_candidate_notebook)
print(job_data_notebook)
# Out:
# s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/sagemaker-automl-candidates/automl-dm-09-20-54-14-pr-1-089f7fafc7044670a1d4183b126dae05343c/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/sagemaker-automl-candidates/automl-dm-09-20-54-14-pr-1-089f7fafc7044670a1d4183b126dae05343c/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# Let's copy these two notebooks.

# %%
# %%sh -s $job_candidate_notebook $job_data_notebook
# aws s3 cp $1 .
# aws s3 cp $2 .
# Out:
# download: s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/sagemaker-automl-candidates/automl-dm-09-20-54-14-pr-1-089f7fafc7044670a1d4183b126dae05343c/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to ./SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-us-east-2-308412838853/sagemaker/DEMO-automl-dm/output/automl-dm-09-20-54-14/sagemaker-automl-candidates/automl-dm-09-20-54-14-pr-1-089f7fafc7044670a1d4183b126dae05343c/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to ./SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# ## Deploying the best candidate, with Amazon SageMaker Model Monitor
# Now that we have successfully completed the AutoML job on our dataset and visualized the trials, we can create a model from any of the trials with a single API call and then deploy that model for online or batch prediction using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html).

# %% [markdown]
# Let's create a SageMaker model for this Inference Pipeline.

# %%
model_name = 'automl-dm-model-' + timestamp_suffix

model_arn = sm.create_model(Containers=best_candidate['InferenceContainers'],
                            ModelName=model_name,
                            ExecutionRoleArn=role)

print('Model ARN: ', model_arn['ModelArn'])
# Out:
# Model ARN:  arn:aws:sagemaker:us-east-2:308412838853:model/automl-dm-model-09-20-54-14

# %% [markdown]
# Let's configure data capture.

# %%
s3_capture_path = 's3://ar52/' + model_name + '/'

print(s3_capture_path)
# Out:
# s3://ar52/automl-dm-model-09-20-54-14/

# %%
data_capture_configuration = {
    "EnableCapture": True, # flag turns data capture on and off
    "DestinationS3Uri": s3_capture_path, # s3 location where captured data is saved
    "InitialSamplingPercentage": 100, # sampling rate to capture data. max is 100%
    "CaptureOptions": [
       {
            "CaptureMode": "Output" # The type of capture this option enables. Values can be: [Output/Input]
        },
        {
            "CaptureMode": "Input" # The type of capture this option enables. Values can be: [Output/Input]
        }
    ],
    "CaptureContentTypeHeader": {
       "CsvContentTypes": ["text/csv"], # headers which should signal to decode the payload into CSV format 
       "JsonContentTypes": ["application/json"] # headers which should signal to decode the payload into JSON format 
    }
}

# %% [markdown]
# As usual, we first create the endpoint configuration, and then the endpoint.

# %%
# Endpoint configuration name
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())
epc_name = 'automl-dm-epc-' + timestamp_suffix
print('Endpoint configuration name:', epc_name)

ep_config = sm.create_endpoint_config(EndpointConfigName = epc_name,
                                      ProductionVariants=[{'InstanceType':'ml.m4.xlarge',
                                                           'InitialInstanceCount':1,
                                                           'ModelName':model_name,
                                                           'VariantName': 'AllTraffic'}],
                                      DataCaptureConfig = data_capture_configuration)
# Out:
# Endpoint configuration name: automl-dm-epc-09-21-22-21

# %%
# Endpoint name
ep_name = 'automl-dm-ep-' + timestamp_suffix
variant_name = 'automl-dm-variant-' + timestamp_suffix
print('Endpoint name:', ep_name)

create_endpoint_response = sm.create_endpoint(EndpointName=ep_name,
                                              EndpointConfigName=epc_name)
# Out:
# Endpoint name: automl-dm-ep-09-21-22-21

# %%
# %%time
sm.get_waiter('endpoint_in_service').wait(EndpointName=ep_name)

resp = sm.describe_endpoint(EndpointName=ep_name)
status = resp['EndpointStatus']

print("Endpoint ARN   : " + resp['EndpointArn'])
print("Endpoint status: " + status)
# Out:
# Endpoint ARN   : arn:aws:sagemaker:us-east-2:308412838853:endpoint/automl-dm-ep-09-21-22-21
# Endpoint status: InService
# CPU times: user 227 ms, sys: 11.5 ms, total: 238 ms
# Wall time: 9min 31s

# %% [markdown]
# ## Scoring the best candidate

# %% [markdown]
# Let's predict and score the test set. We'll compute metrics ourselves just for fun.

# %%
tp = tn = fp = fn = count = 0

with open('automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   # Skip header
        l = l.split(',')  # Split CSV line into features
        label = l[-1]     # Store 'yes'/'no' label
        l = l[:-1]        # Remove label
        l = ','.join(l)   # Rebuild CSV line without label
                
        response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=l)

        response = response['Body'].read().decode("utf-8")
        #print ("label %s response %s" %(label,response))

        if 'yes' in label:
            # Sample is positive
            if 'yes' in response:
                # True positive
                tp=tp+1
            else:
                # False negative
                fn=fn+1
        else:
            # Sample is negative
            if 'no' in response:
                # True negative
                tn=tn+1
            else:
                # False positive
                fp=fp+1
        count = count+1
        if (count % 100 == 0):   
            sys.stdout.write(str(count)+' ')
            
print ("Done")
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 Done

# %%
# Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall    = tn/(tn+fn)
f1        = (2*precision*recall)/(precision+recall)

print ("Accuracy: %.4f, Precision: %.4f, Recall: %.4f, F1: %.4f" % (accuracy, precision, recall, f1))
# Out:
# 1718 104
# 81 157
# Accuracy: 0.9102, Precision: 0.6015, Recall: 0.9550, F1: 0.7381

# %% [markdown]
# Let's check that we captured data.

# %%
# !aws s3 ls --recursive s3://ar52/

# %%
# %%sh -s "$s3_capture_path"
#
# aws s3 ls --recursive $1
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-29-37307fa9b8b9> in <module>
# ----> 1 get_ipython().run_cell_magic('sh', '-s "$s3_capture_path"', '\naws s3 ls --recursive $1\n')
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2350             with self.builtin_trap:
#    2351                 args = (magic_arg_s, cell)
# -> 2352                 result = fn(*args, **kwargs)
#    2353             return result
#    2354
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# </opt/conda/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\naws s3 ls --recursive $1\n'' returned non-zero exit status 1.

# %%
# %%sh -s "$s3_capture_path"
#
# aws s3 cp --recursive $1 .

# %%
# !head <filename>

# %% [markdown]
# ## Deleting the endpoint
# Once that we're done predicting, we can delete the endpoint (and stop paying for it).

# %%
# Uncomment to delete
#sm.delete_endpoint(EndpointName=ep_name)

# %% [markdown]
# ### https://gitlab.com/juliensimon/aim307
# ### Twitter: @julsimon
